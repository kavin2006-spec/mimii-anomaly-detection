# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import os

# ── CONFIG ── adjust this path to match your actual folder structure
DATA_ROOT = "../data/raw/fan/6dB"
MACHINE_ID = "id_00"

normal_dir = os.path.join(DATA_ROOT, MACHINE_ID, "normal")
abnormal_dir = os.path.join(DATA_ROOT, MACHINE_ID, "abnormal")

# Pick one file from each
normal_file = os.path.join(normal_dir, os.listdir(normal_dir)[0])
abnormal_file = os.path.join(abnormal_dir, os.listdir(abnormal_dir)[0])

print(f"Normal file:   {normal_file}")
print(f"Abnormal file: {abnormal_file}")

# Load both
y_normal, sr = librosa.load(normal_file, sr=16000)
y_abnormal, sr = librosa.load(abnormal_file, sr=16000)

print(f"\nSample rate: {sr} Hz")
print(f"Duration: {len(y_normal)/sr:.1f} seconds")
print(f"Samples: {len(y_normal)}")
